# %% [markdown]
# ### DataSet Description

# %%
# loading the dataset
#synthetic dataset

import pandas as pd
df=pd.read_csv('bank-details.csv')

# %%
df.index = df.index + 1

# %%
df
# Out:
#    Account_no   Pin              Name Gender          Branch_name  Branch_no  \
# 1      AC1020  1133            Prasad      M           whitefield          4
# 2      AC1021  5413      Sumit khosla      M         basavanagudi          7
# 3      AC1022  9037      Rajni shenoy      F          vijayanagar          1
# 4      AC1023  6905  Harshitha simoga      F          vijayanagar          1
# 5      AC1024  8251    Anitha Trivedi      F        chandralayout          6
# 6      AC1025  4603       Akash coorg      M            yelahanka          8
# 7      AC1026  7823         Jeshwanth      M           whitefield          4
# 8      AC1027  7915       Dhakshayini      F   mahalakshmi layout          2
# 9      AC1028  3182             Disha      F       bashyam circle          3
# 10     AC1029  5370           Ghousia      F   mahalakshmi layout          2
# 11     AC1030  2870          Samiulla      F         basavanagudi          7
# 12     AC1031  4784   Divya Manjunath      F            yelahanka          8
# 13     AC1032  9092     Ahan samdhani      M          vijayanagar          1
# 14     AC1033  7866         Rajshekar      M           kormangala          5
# 15     AC1034  1471    Rhutuja Asekar      M         basavanagudi          7
# 16     AC1035  3012            Yashas      M        chandralayout          6
# 17     AC1036  8714          Prathiba      F           kormangala          5
# 18     AC1037  5788           Manjula      F           kormangala          5
# 19     AC1038  7264        Dhevadutta      M       bashyam circle          3
# 20     AC1039  3120            Rohini      F            yelahanka          8
# 21     AC1040  6070         Nagashree      F           whitefield          4
# 22     AC1041  1218            Rohith      F            yelahanka          8
# 23     AC1042  1537         Basavaraj      M   mahalakshmi layout          2
# 24     AC1043  8345             Kiran      M        chandralayout          6
# 25     AC1044  7179           Mamatha      F       bashyam circle          3
# 26     AC1045  2681         Yuvashree      F          vijayanagar          1
# 27     AC1046  9182      Ramya rajesh      F        chandralayout          6
# 28     AC1047  7509           Roopesh      M           whitefield          4
# 29     AC1048  5636            Faisal      M   mahalakshmi layout          2
# 30     AC1049  2022    Mrinal Mangoli      M       bashyam circle          3
#
#       Phone_no                    E-mail_id  Age  \
# 1   9986543678            prasu19@gmail.com   28
# 2   9633674568           sumitkho@gmail.com   45
# 3   9654258135       shenoy_rajni@gmail.com   67
# 4   9864367832            harsh03@gmail.com   21
# 5   8689763134  anithatrivedi11@hotmail.com   56
# 6   9988577886          coorg_047@gmail.com   34
# 7   9445567782        jeshwanth83@gmail.com   58
# 8   8887521136            dak$h@hotmail.com   78
# 9   7452633981        dishaaa1234@gmail.com   34
# 10  7893214523             ghozia@gmail.com   53
# 11  8885522366    samiullashareef@gmail.com   87
# 12  9342561818           manju#43@gmail.com   66
# 13  9134672901   ahan87samdhani@hotmail.com   34
# 14  8867778904     shekarofficial@gmail.com   52
# 15  9342578191      rhutujaaselar@yahoo.com   41
# 16  9342576161             yash@hotmail.com   28
# 17  9432786210       pratibha1931@gmail.com   90
# 18  8876668903          manjubabi@gmail.com   45
# 19  7843647127     dhevadutta1234@gmial.com   64
# 20  8864219181               ro47@yahoo.com   38
# 21  9342456781  nagashree_abc11@hotmail.com   59
# 22  9880964077              rohit@gmail.com   40
# 23  8862791819      basavaraj2000@gmail.com   20
# 24  8884087388              kirAn@gmail.com   70
# 25  9483217476      mamathaindepe@yahoo.com   75
# 26  9480706548            yuvandy@gmail.com   78
# 27  7338342613       ramya_rajesh@gmail.com   35
# 28  9164372708    roopeshthegr8@hotmail.com   37
# 29  9620186712          fai_sal63@gmail.com   67
# 30  9748914290           mr_mango@gmail.com   25
#
#                                               Address  Balance
# 1                #81, 5th main, whitefield, bangalore  5607000
# 2   #456, 2nd block, sumeru apt, basavangudi, bang...    90000
# 3             #3565, "ramnath", hampinagar, bangalore   250000
# 4             #841, 2nd stage, vijayanagar, bangalore    46000
# 5                           #21, nagarbhavi,bangalore   367000
# 6             #567, New BEL, 8th main road, bangalore    97000
# 7   #121, 4th stage, 5th main road, whitefield, ba...   300000
# 8   #787, rajkumar road, mahalakshmi layout, banga...   500000
# 9                         #26, rajajinagar, bangalore    65000
# 10         mahalakshmilayout metro station, bangalore    94000
# 11        #89, 8th main road, basavanagudi, bangalore  6000000
# 12                      yelahanka old town, bangalore   430000
# 13   #243, old alarimara road, vijayanagar, bangalore    75000
# 14  "street treat", 9th main road, kormangala, ban...    92000
# 15          #45, orchid apts, basavanagudi, bangalore     5000
# 16     #908, near nammauru thindi, kengeri, bangalore    64000
# 17    #98, near appolo hospital, kormangala.bangalore  4500000
# 18    #98, near appolo hospital, kormangala.bangalore    76000
# 19  #32, 4th stage, 6th main road, bashyam circle,...    54000
# 20  #80, 4th main road, near new town bus stand,ye...    86425
# 21  #2245, gurukul apts, 11th main road, whitefild...   327500
# 22       #781, doddabommasandra, yelahanka, bangalore    75395
# 23      #7801, old oak apts, rajkumar road, bangalore    50423
# 24  #52, green wood apts, 1st stage,18th road, nag...   753469
# 25                #63,navrang circle, bashyam circle   9662420
# 26            #345, 2nd stage, manuvana, Vijayanagar   7852390
# 27     #999,3rd stage, dollars colony, Chandralayout     56391
# 28        #45,5th block, babusingh nagar, white field    58960
# 29               #503, 2nd block, Maha Lakshmi Layout  4598723
# 30          #1051,rajajinagar 5th block, Bangalore 10   602500

# %%
# checking the length of the dataframe

len(df)
# Out:
# 30

# %% [markdown]
# ### login page

# %%
#creating a list to store a particular attribute value after converting it to lower case 

df_name=[]
df_acco=[]
df_pin=[]
df_name=df.Name.str.lower()
df_acco=df.Account_no.str.lower()
df_pin=df.Pin

# %%
def checkName(name: str, j: int) -> bool:
    if name == df_name.iloc[j]:
        return True
    return False

# %%
def checkAcc(acc_num: str, j: int) -> bool:
    if acc_num == df_acco.iloc[j]:
        return True
    return False

# %%
def checkPin(pin: int, j: int) -> bool:
    if pin == df_pin.iloc[j]:
        return True
    return False

# %%
def check(detail, i):
    for j in range(0, len(df)):
        if i == 0:
            if checkName(detail, j):
                return j
        if i == 1:
            if checkAcc(detail, j):
                return j
        if i == 2:
            if checkPin(detail, j):
                return j
    return False

# %%
#Recursive function to input the username and to check if the entry is present in the dataset or not.

def details():
    while True:
        name = input("Enter your Name:")
        if check(name.lower(), i = 0) is not False:
            print("\033[1m  NAME VALIDATED\n" + "\033[0m")
            p1 = check(name.lower(), i = 0)
            account_num = input("Enter your Account Number:")
            if check(account_num.lower(), i = 1) is not False:
                print("\033[1m  ACCOUNT NUMBER VALIDATED\n" + "\033[0m")
                p2 = check(account_num.lower(), i = 1)
                pin = int(input("Enter your Pin Number:"))
                if check(pin, i = 2) is not False:
                    print("\033[1m  PIN NUMBER VALIDATED\n" + "\033[0m")
                    p3 = check(pin, i = 2)
                    if p1 == p2 and p2 == p3:
                        return p1
                    else:
                        print("\033[1m  INVALID Details\n" + "\033[0m")
                else:
                    print("\033[1m  INVALID PIN NUMBER\n" + "\033[0m")
            else:
                print("\033[1m  INVALID ACCOUNT NUMBER\n" + "\033[0m")
        else:
            print("\033[1m  INVALID USERNAME\n" + "\033[0m")

# %%
def checkLength(phone_number: str) -> bool:
    if len(phone_number) == 10:
        return True
    return False

# %%
import random
def checkOTP():
    rand=random.randrange(1000,10000)
    print("\033[0;30mAn OTP from CACHE BANK:", rand)
    OTP = int(input("Enter the OTP received to check for authentication :"))
    if rand == OTP:
        print("\033[0;31m \t\t\t\t\t\t ACCESS GRANTED " +"\033[0;30m")
        return
    else:
        print("\033[0;31m \t\t\t\tINCORRECT OTP..TIME LAPSED..NEED TO LOGIN AGAIN" +"\033[0;30m")

# %%
#recursive function to input the phone number and to check if its valid combination or not.

def checkPhoneNumber():
    while True:
        phone_number=input("Enter you Phone Number : ")
        if checkLength(phone_number):
            print("\033[0;31m \t\t\t\t\t CAN PROCEED TO NEXT STEP\n\n" +"\033[0;30m")
            if checkOTP():
                print("\033[1m  PHONE NUMBER IS VALID\n"+ "\033[0m")
                return 
            return
        else:
            print("\033[1m  PERMISSION NOT GRANTED ...PLEASE RE-ENTER THE PHONE NUMBER\n" + "\033[0m")

# %%
def Verification():
    print("\033[0;30mx"*127)
    print("\033[1m \033[34m \033[4m \t\t\t\t\t\t\t CACHE BANK" +"\033[1m \033[34m \033[4m")
    print("\033[0;30mx"*127)
    print("\n")
    p = details()
    checkPhoneNumber()
    print("\n")
    print("\033[0;30mx"*127)
    return p

p = Verification() + 1
# Out:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#    							 CACHE BANK
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Enter your Name:Disha
#   NAME VALIDATED
#
# Enter your Account Number:AC1028
#   ACCOUNT NUMBER VALIDATED
#
# Enter your Pin Number:3182
#   PIN NUMBER VALIDATED
#
# Enter you Phone Number : 7452633981
#  					 CAN PROCEED TO NEXT STEP
#
#
# An OTP from CACHE BANK: 2975
# Enter the OTP received to check for authentication :2975
#  						 ACCESS GRANTED
#
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ### Features

# %%
# to display date n time

import datetime
now=datetime.datetime.now()

# %%
def Menu():
    print("1. Credit Denomination\n2. Debit Denominaton\n3. Change your PIN\n4. Mini Statement\n5. Quit")

# %%
def credit(credit_amt):
    if credit_amt > 0:
        df.at[p, 'Balance'] += credit_amt
        amt = df.loc[p,'Balance']
        df.loc[p,'Balance'] = amt
        df.to_csv("bank-details.csv")
        print("Your amount has been successfully deposited to your account")
        print("Your current balance is:")
        print("Balance : " , df.loc[p]['Balance'])
        print("\033[1mThanks for using CACHE BANK" +"\033[1m")
    else:
        print("\033[1mIvalid amount to proceed...Operation Unsuccessful" +"\033[1m")

# %%
def debit(debit_amt):
    if debit_amt < (df.iloc[p]['Balance']):
        print("Collect your cash!")
        df.at[p,'Balance'] -= debit_amt
        amt = df.loc[p,'Balance']
        df.loc[p,'Balance'] = amt
        df.to_csv("bank-details.csv")
        print("Your current balance is:")
        print("Balance : " , df.loc[p]['Balance'])
        print("\033[1mThanks for using CACHE BANK" +"\033[1m")
    else:
        print("\033[1mNo sufficient balance...Operation Failed" +"\033[1m")

# %%
def changePin():
    print("\n"+"\033[0;30mx"*127)
    change_pin = input("\033[1mEnter new PIN here : " +"\033[1m");
    length = len(change_pin) 
    if length == 4:
        print("\033[1mYour PIN has been successfully changed..! " +"\033[1m")
        print("New PIN: "+change_pin)
        df.loc[p,'Pin'] = change_pin
        df.to_csv("bank-details.csv")
        print("\033[1mThanks for using CACHE BANK" +"\033[1m")
    else:
        print("\033[1mIvalid PIN to proceed....Operation Failed" +"\033[1m ")

# %%
def miniStatement():
    print("\033[1mDate and Time : " +"\033[1m " +now.strftime('%d - %m - %y %H:%M:%S'))
    print("\n"+"\033[0;30mx"*127)
    print("\033[1mPlease collect your mini statement" +"\033[1m ")
    print(df.loc[p])        
    print("\033[1mThanks for using CACHE BANK" +"\033[1m ")

# %%
#Net-Banking operations(credit,debit,to change PIN, to check balance and to quit)

print("\033[0;30mx"*127)
print("\033[1m \033[34m \033[4m \t\t\t\t\t\t\t CACHE BANK" +"\033[1m \033[34m \033[4m")
print("\033[0;30mx"*127)

def operations():
    while True:
        Menu()
        ch = int(input("\033[1m Select Operation:" +"\033[1m"))
        if ch == 1:
            print("\n"+"\033[0;30mx"*127)
            print("\033[1mBalance : "+"\033[1m" , df.loc[p]['Balance'])
            credit_amt = int(input("Enter your amount to be credited: " +"\033[1m"))
            credit(credit_amt)
            print("\n"+"\033[0;30mx"*127)
        elif ch == 2:
            print("\n"+"\033[0;30mx"*127)
            print("\033[1mBalance : " +"\033[1m", df.loc[p]['Balance'])
            debit_amt = int(input("Enter your amount to proceed:"))
            debit(debit_amt)
            print("\n"+"\033[0;30mx"*127)
        elif ch == 3:
            print("\n"+"\033[0;30mx"*127)
            changePin()
            Verification()
            print("\n"+"\033[0;30mx"*127)
        elif ch == 4:
            print("\n"+"\033[0;30mx"*127)
            miniStatement()
            print("\n"+"\033[0;30mx"*127)
        elif ch == 5:
            print("\n"+"\033[0;30mx"*127)
            quit1 = input("\033[1mPress Y to quit...!" +"\033[1m ")
            if quit1 == "Y":
                print("Quit")
                return
            else:
                print("\033[1mChoose any transaction please:"+"\033[1m ")
            print("\n"+"\033[0;30mx"*127)
        else:
            print("\033[1mInvalid Input" +"\033[1m ")
            return
operations()
# Out:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#    							 CACHE BANK
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 1. Credit Denomination
# 2. Debit Denominaton
# 3. Change your PIN
# 4. Mini Statement
# 5. Quit
#  Select Operation:1
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Balance :  65000
# Enter your amount to be credited: 4000
# Your amount has been successfully deposited to your account
# Your current balance is:
# Balance :  69000
# Thanks for using CACHE BANK
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 1. Credit Denomination
# 2. Debit Denominaton
# 3. Change your PIN
# 4. Mini Statement
# 5. Quit
#  Select Operation:4
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Date and Time :  29 - 08 - 21 20:27:20
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Please collect your mini statement
# Account_no                           AC1028
# Pin                                    3182
# Name                                  Disha
# Gender                                    F
#  Branch_name                 bashyam circle
# Branch_no                                 3
# Phone_no                         7452633981
# E-mail_id             dishaaa1234@gmail.com
# Age                                      34
# Address         #26, rajajinagar, bangalore
# Balance                               69000
# Name: 9, dtype: object
# Thanks for using CACHE BANK
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 1. Credit Denomination
# 2. Debit Denominaton
# 3. Change your PIN
# 4. Mini Statement
# 5. Quit
#  Select Operation:5
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Press Y to quit...! Y
# Quit

# %%
df
# Out:
#    Account_no   Pin              Name Gender          Branch_name  Branch_no  \
# 1      AC1020  1133            Prasad      M           whitefield          4
# 2      AC1021  5413      Sumit khosla      M         basavanagudi          7
# 3      AC1022  9037      Rajni shenoy      F          vijayanagar          1
# 4      AC1023  6905  Harshitha simoga      F          vijayanagar          1
# 5      AC1024  8251    Anitha Trivedi      F        chandralayout          6
# 6      AC1025  4603       Akash coorg      M            yelahanka          8
# 7      AC1026  7823         Jeshwanth      M           whitefield          4
# 8      AC1027  7915       Dhakshayini      F   mahalakshmi layout          2
# 9      AC1028  3182             Disha      F       bashyam circle          3
# 10     AC1029  5370           Ghousia      F   mahalakshmi layout          2
# 11     AC1030  2870          Samiulla      F         basavanagudi          7
# 12     AC1031  4784   Divya Manjunath      F            yelahanka          8
# 13     AC1032  9092     Ahan samdhani      M          vijayanagar          1
# 14     AC1033  7866         Rajshekar      M           kormangala          5
# 15     AC1034  1471    Rhutuja Asekar      M         basavanagudi          7
# 16     AC1035  3012            Yashas      M        chandralayout          6
# 17     AC1036  8714          Prathiba      F           kormangala          5
# 18     AC1037  5788           Manjula      F           kormangala          5
# 19     AC1038  7264        Dhevadutta      M       bashyam circle          3
# 20     AC1039  3120            Rohini      F            yelahanka          8
# 21     AC1040  6070         Nagashree      F           whitefield          4
# 22     AC1041  1218            Rohith      F            yelahanka          8
# 23     AC1042  1537         Basavaraj      M   mahalakshmi layout          2
# 24     AC1043  8345             Kiran      M        chandralayout          6
# 25     AC1044  7179           Mamatha      F       bashyam circle          3
# 26     AC1045  2681         Yuvashree      F          vijayanagar          1
# 27     AC1046  9182      Ramya rajesh      F        chandralayout          6
# 28     AC1047  7509           Roopesh      M           whitefield          4
# 29     AC1048  5636            Faisal      M   mahalakshmi layout          2
# 30     AC1049  2022    Mrinal Mangoli      M       bashyam circle          3
#
#       Phone_no                    E-mail_id  Age  \
# 1   9986543678            prasu19@gmail.com   28
# 2   9633674568           sumitkho@gmail.com   45
# 3   9654258135       shenoy_rajni@gmail.com   67
# 4   9864367832            harsh03@gmail.com   21
# 5   8689763134  anithatrivedi11@hotmail.com   56
# 6   9988577886          coorg_047@gmail.com   34
# 7   9445567782        jeshwanth83@gmail.com   58
# 8   8887521136            dak$h@hotmail.com   78
# 9   7452633981        dishaaa1234@gmail.com   34
# 10  7893214523             ghozia@gmail.com   53
# 11  8885522366    samiullashareef@gmail.com   87
# 12  9342561818           manju#43@gmail.com   66
# 13  9134672901   ahan87samdhani@hotmail.com   34
# 14  8867778904     shekarofficial@gmail.com   52
# 15  9342578191      rhutujaaselar@yahoo.com   41
# 16  9342576161             yash@hotmail.com   28
# 17  9432786210       pratibha1931@gmail.com   90
# 18  8876668903          manjubabi@gmail.com   45
# 19  7843647127     dhevadutta1234@gmial.com   64
# 20  8864219181               ro47@yahoo.com   38
# 21  9342456781  nagashree_abc11@hotmail.com   59
# 22  9880964077              rohit@gmail.com   40
# 23  8862791819      basavaraj2000@gmail.com   20
# 24  8884087388              kirAn@gmail.com   70
# 25  9483217476      mamathaindepe@yahoo.com   75
# 26  9480706548            yuvandy@gmail.com   78
# 27  7338342613       ramya_rajesh@gmail.com   35
# 28  9164372708    roopeshthegr8@hotmail.com   37
# 29  9620186712          fai_sal63@gmail.com   67
# 30  9748914290           mr_mango@gmail.com   25
#
#                                               Address  Balance
# 1                #81, 5th main, whitefield, bangalore  5607000
# 2   #456, 2nd block, sumeru apt, basavangudi, bang...    90000
# 3             #3565, "ramnath", hampinagar, bangalore   250000
# 4             #841, 2nd stage, vijayanagar, bangalore    46000
# 5                           #21, nagarbhavi,bangalore   367000
# 6             #567, New BEL, 8th main road, bangalore    97000
# 7   #121, 4th stage, 5th main road, whitefield, ba...   300000
# 8   #787, rajkumar road, mahalakshmi layout, banga...   500000
# 9                         #26, rajajinagar, bangalore    69000
# 10         mahalakshmilayout metro station, bangalore    94000
# 11        #89, 8th main road, basavanagudi, bangalore  6000000
# 12                      yelahanka old town, bangalore   430000
# 13   #243, old alarimara road, vijayanagar, bangalore    75000
# 14  "street treat", 9th main road, kormangala, ban...    92000
# 15          #45, orchid apts, basavanagudi, bangalore     5000
# 16     #908, near nammauru thindi, kengeri, bangalore    64000
# 17    #98, near appolo hospital, kormangala.bangalore  4500000
# 18    #98, near appolo hospital, kormangala.bangalore    76000
# 19  #32, 4th stage, 6th main road, bashyam circle,...    54000
# 20  #80, 4th main road, near new town bus stand,ye...    86425
# 21  #2245, gurukul apts, 11th main road, whitefild...   327500
# 22       #781, doddabommasandra, yelahanka, bangalore    75395
# 23      #7801, old oak apts, rajkumar road, bangalore    50423
# 24  #52, green wood apts, 1st stage,18th road, nag...   753469
# 25                #63,navrang circle, bashyam circle   9662420
# 26            #345, 2nd stage, manuvana, Vijayanagar   7852390
# 27     #999,3rd stage, dollars colony, Chandralayout     56391
# 28        #45,5th block, babusingh nagar, white field    58960
# 29               #503, 2nd block, Maha Lakshmi Layout  4598723
# 30          #1051,rajajinagar 5th block, Bangalore 10   602500

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# #### Analysis of users, according to Branch wise

# %%
import seaborn as sns 
sns.countplot(x = 'Branch_no', data = df)
# Out:
# <AxesSubplot:xlabel='Branch_no', ylabel='count'>

# %% [markdown]
# #### Analysis of users, on Gender and Branch no

# %%
sns.lineplot(x="Gender", y="Branch_no", data = df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Branch_no'>

# %% [markdown]
# #### Analysis of users, on Gender basis

# %%
sns.countplot(x = 'Gender', data = df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Analysis of users, on Gender and Age

# %%
sns.stripplot(x='Gender', y='Age', data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>
